# %% [markdown]
# ## Demo: Edge detection using Sobel operator in OpenCV
#
# ---
#
# Prof. Dr.-Ing. Antje Muntzinger, Hochschule für Technik Stuttgart
#
# antje.muntzinger@hft-stuttgart.de
#
# ---

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load an image in grayscale
img = cv2.imread('../images/palmtrees.jpg', cv2.IMREAD_GRAYSCALE)

# display image
plt.imshow(img, cmap='gray')

# %%
# Apply Sobel operator
sobelx = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=9)
sobely = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=9)

# Calculate gradient magnitude
magnitude = np.sqrt(sobelx**2 + sobely**2)

# Normalize for display
magnitude = cv2.normalize(magnitude, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8U)

# Display results
plt.figure(figsize=(15,15))
plt.subplot(221), plt.imshow(img, cmap='gray'), plt.title('Original')
plt.subplot(222), plt.imshow(sobelx, cmap='gray'), plt.title('Sobel X')
plt.subplot(223), plt.imshow(sobely, cmap='gray'), plt.title('Sobel Y')
plt.subplot(224), plt.imshow(magnitude, cmap='gray'), plt.title('Gradient Magnitude')
plt.show()
